# %%
import pandas as pd
import zipfile
import json
import sqlite3
from pathlib import Path
from sqlalchemy import create_engine
from sqlalchemy import URL
from sqlalchemy import select
from sqlalchemy.orm import Session
from sqlalchemy import text
from sqlalchemy.orm import declarative_base, sessionmaker
from sqlalchemy import Column
from sqlalchemy import String, Integer
# Создание базы данных в файле test.db 
connection = sqlite3.connect('hw1.db')
# Создаем курсор
cursor = connection.cursor()
# Оператор SQL для создания таблицы
create_names_table = """
CREATE TABLE IF NOT EXISTS telecom_companies(
    ogrn INTEGER,
    inn INTEGER,
    kpp INTEGER,
    name TEXT,
    okved TEXT 
)
"""

# Запускаем команду создания таблицы
cursor.execute(create_names_table)

# Фиксируем изменения
connection.commit()

# %%
with zipfile.ZipFile('archive.zip', 'r') as f:
    file_names = f.namelist()
    for name in file_names:
        f.extract(name)
        with open (name, 'r', encoding='utf8') as file:
            base = json.load(file)
            for i in range(len(base)):
                try:
                    if base['data']['СвОКВЭД']['СвОКВЭДОсн']['КодОКВЭД'] in okved_61:
                        ogrn = base['ogrn']
                        inn = base['inn']
                        kpp = base['kpp']
                        name = base['name']
                        okved = base['data']['СвОКВЭД']['СвОКВЭДОсн']['КодОКВЭД']
                        cursor = connection.cursor()
                        row (int(inn),int(kpp),int(ogrn),okved,name)
                        cursor.execute(insert_rows,row)
                        connection.commit
                except Exception:
                    print('error')
                    continue                             
                ## Удаляем файл
        path = Path(name)
        path.unlink()

# %%
# Оператор SQL для вставки данных в таблицу 
insert_data = """
INSERT INTO telecom_companies (ogrn, inn, kpp, name, okved)
VALUES (?, ?, ?, ?, ?,)
"""
with zipfile.ZipFile('archive.zip', 'r') as f:
    file_names = f.namelist()
    for name in file_names:
        f.extract(name)
        with open (name, 'r', encoding='utf8') as file:
            base = json.load(file)
            for i in range(len(base)):
                try:
                    if base['data']['СвОКВЭД']['СвОКВЭДОсн']['КодОКВЭД'] in okved_61:
                        ogrn = base['ogrn']
                        inn = base['inn']
                        kpp = base['kpp']
                        name = base['name']
                        okved = base['data']['СвОКВЭД']['СвОКВЭДОсн']['КодОКВЭД']
                        row (int(inn),int(kpp),int(ogrn),okved,name)
                        cursor.execute(insert_rows,row) # Запускаем команду вставки данных
                        connection.commit() # Фиксируем изменения
                except:
                    continue                             
                ## Удаляем файл
        path = Path(name)
        path.unlink()

# %%
# Out:
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# ...
